# %%
import pandas as pd

# %%
df = pd.read_csv('data\\csv\\benchmark_all_models_20250828-183014.csv')

# %%
df
# Out:
#               model  n_tickers  ann_return   ann_vol    sharpe  max_drawdown  \
# 0     claude_sonnet         25    0.150901  0.177190  0.941096     -0.176669
# 1            grok_4         20    0.161496  0.179296  0.981530     -0.162382
# 2   llama4_maverick         19    0.062434  0.153182  0.550856     -0.152865
# 3       deepseek-r1         20    0.164711  0.171998  1.033699     -0.167155
# 4       deepseek-v3         20    0.174944  0.176531  1.067510     -0.166369
# 5            gpt-4o         20    0.136950  0.178069  0.855459     -0.166072
# 6       gpt-4o-mini         25   -0.079078  0.110768  0.396445     -0.046728
# 7        gpt-5-mini         20    0.129172  0.187029  0.806171     -0.168849
# 8        gpt-5-nano         25    0.130041  0.194115  0.776562     -0.194348
# 9             gpt-5         24    0.102551  0.150393  0.798859     -0.129981
# 10               o3         20    0.040180  0.145656  0.407923     -0.146451
# ...
